# %% [markdown]
# # GIT Sync Notebook

# %%
# !pip install --quiet python-dotenv

# %%
import time
import os
import pathlib
import shutil
import dotenv

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# %pwd

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/FastaiColabNotebooks'

# %%
# %pwd

# %%
# %ls

# %%
#Load Env File
dotenv.load_dotenv('/content/drive/MyDrive/.env')

# %%
# retrive environment variables
name = os.getenv('GIT_USER_NAME')
email = os.getenv('GIT_USER_EMAIL')
git_token = os.getenv('GIT_TOKEN')
git_repo = os.getenv('GIT_REPO')

# %%
# set gloable parameters
# !git config --global user.name {name}
# !git config --global user.email {email}

# %%
# !git rm --cached .env -f

# %%
# !git rm --cached *.jpg -f

# %%
# !git rm --cached *.pkl -f

# %%
# !git status

# %%
# !git add .

# %%
# !git rm --cached FastaiColabNotebooks -f

# %%
# !git status

# %%
# !git commit -m "Modified Notebook"

# %%
#!git remote remove origin
#!git remote add origin https://{git_token}@github.com/{name}/{git_repo}
# !git remote set-url origin https://{git_token}@github.com/{name}/{git_repo}
# !git push --set-upstream origin main

# %%
#!git push

# %% [markdown]
# # Clean Up

# %%
#os.listdir('/content/drive/MyDrive/Colab Notebooks/FastaiColabNotebooks/FastaiColabNotebooks/')

# %%
#shutil.rmtree('/content/drive/MyDrive/Colab Notebooks/FastaiColabNotebooks/FastaiColabNotebooks/')
