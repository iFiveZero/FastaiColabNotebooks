# %% [markdown]
# # GIT Sync Notebook

# %%
# !pip install --quiet python-dotenv

# %%
import time
import os
import pathlib
import shutil
import dotenv

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# %pwd

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/FastaiColabNotebooks'

# %%
# %pwd

# %%
# %ls

# %%
#Load Env File
dotenv.load_dotenv('./.env')

# %%
# retrive environment variables
name = os.getenv('GIT_USER_NAME')
email = os.getenv('GIT_USER_EMAIL')

# %%
# set gloable parameters
# !git config --global user.name {name}
# !git config --global user.email {email}

# %%
#To Update access token
#!git_token = os.getenv('GIT_TOKEN')
#!git_repo = os.getenv('GIT_REPO')
#!git clone https://{git_token}@github.com/{username}/{git_repo}

# %%
# !git rm --cached .env -f

# %%
# !git status

# %%
# !git add .

# %%
# !git commit -m "Modified Notebook"

# %%
# !git push
